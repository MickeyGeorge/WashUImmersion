# %% [markdown]
# # Project Kaggle
#
# In this project, you will be using XGBoost to compete in the social influence competition: https://www.kaggle.com/c/predict-who-is-more-influential-in-a-social-network
#
# We focus on this project since its data size is manageable and we can easily manipulate it.
#
# You need to:
# 1. Read and understand the competition objective
# 2. Download the data for this competition
# 3. Constructive an XGBoost model for this competition
# 4. Tune your XGBoost model
# 5. Submit your results

# %%
import pandas as pd
import numpy as np
import xgboost as xgb

train = pd.read_csv("./all/train.csv")
test = pd.read_csv("./all/test.csv")
train.head()
# Out:
#    Choice  A_follower_count  A_following_count  A_listed_count  \
# 0       0               228                302               3
# 1       0             21591               1179             228
# 2       0              7310               1215             101
# 3       0                20                  7               2
# 4       1             45589                862            2641
#
#    A_mentions_received  A_retweets_received  A_mentions_sent  A_retweets_sent  \
# 0             0.583979             0.100503         0.100503         0.100503
# 1            90.456506            25.798292         5.709329         1.111159
# 2            25.503644             9.556347         5.361519         0.591206
# 3             7.690824             0.277306         1.331508         0.100503
# 4           148.854279            36.998884        27.881768         3.333492
#
#      A_posts  A_network_feature_1         ...           B_following_count  \
# ...

# %%
# Feature engineering
# Compute the following features:
#   - followers/following
#   - mentions received/sent
#   - retweets received/sent
#   - followers/posts
#   - retweets received/posts
#   - mentions received/posts

def ratio(df, user, name1, name2, new_name, factor = 1):
    df[user + "_" + new_name] = (df[user + "_" + name1]+factor)/(df[user + "_" + name2]+factor)
    return df

def get_data(df):
    new_data_set = df.iloc[:, 1:23]
    for user in ["A", "B"]:
        new_data_set = ratio(new_data_set, user, "follower_count", "following_count", "follower_ratio")
        new_data_set = ratio(new_data_set, user, "mentions_received", "mentions_sent", "mention_ratio")
        new_data_set = ratio(new_data_set, user, "retweets_received", "retweets_sent", "retweet_ratio")
        new_data_set = ratio(new_data_set, user, "follower_count", "posts", "follow_post")
        new_data_set = ratio(new_data_set, user, "retweets_received", "posts", "retweet_post")
        new_data_set = ratio(new_data_set, user, "mentions_received", "posts", "mention_post")
    names = ["_".join(x.split("_")[1:]) for x in [x for x in new_data_set.columns if "A" in x]]
    for name in names:
        new_data_set[name+"_diff"] = new_data_set["A_"+name] - new_data_set["B_"+name]
    X = new_data_set
    y = df.iloc[:,0]
    data_dmatrix = xgb.DMatrix(data=X,label=y)
    return data_dmatrix

# %%
# Use cross-validation to find the best parameter
data_dmatrix = get_data(train)
params = {"objective":"binary:logistic",'eval_metric': 'auc', 
          "eta":0.005, "gamma":1, "lambda":3, "max_depth":4, "min_child_weight":1,
          "verbose":False, "subsample":0.8, "colsample_bytree":0.8}

cv_result = xgb.cv(dtrain = data_dmatrix, nfold = 5, params=params,num_boost_round=3000)
np.max(cv_result["test-auc-mean"])
# Out:
# [14:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=4
# [14:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=4
# [14:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# ...

# %%
# Train the model
model = xgb.train(dtrain = data_dmatrix, params=params,num_boost_round=3000)
# Out:
# [14:56:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:56:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:56:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:56:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:56:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:56:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:56:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [14:56:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# ...

# %%
# Prepare the testing data and predict on it
def process_test_data(df_test):
    new_data_set = df_test
    for user in ["A", "B"]:
        new_data_set = ratio(new_data_set, user, "follower_count", "following_count", "follower_ratio")
        new_data_set = ratio(new_data_set, user, "mentions_received", "mentions_sent", "mention_ratio")
        new_data_set = ratio(new_data_set, user, "retweets_received", "retweets_sent", "retweet_ratio")
        new_data_set = ratio(new_data_set, user, "follower_count", "posts", "follow_post")
        new_data_set = ratio(new_data_set, user, "retweets_received", "posts", "retweet_post")
        new_data_set = ratio(new_data_set, user, "mentions_received", "posts", "mention_post")
    names = ["_".join(x.split("_")[1:]) for x in [x for x in new_data_set.columns if "A" in x]]
    for name in names:
        new_data_set[name+"_diff"] = new_data_set["A_"+name] - new_data_set["B_"+name]
    return new_data_set

df_test = process_test_data(test)
preds = model.predict(xgb.DMatrix(df_test), ntree_limit=model.best_ntree_limit)

# %%
df_submission = pd.DataFrame({"Id":range(1,len(preds)+1), "Choice":preds})
df_submission.to_csv("~/Downloads/submission.csv", index=False)
